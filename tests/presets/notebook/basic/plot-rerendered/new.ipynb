# %% [markdown]
# # Rainfall summary
#
# A short look at a month of rainfall readings.

# %% [raw]
# dataset: rainfall-2026-07
# source: station 14

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(20260819)

# %%
readings = np.random.default_rng().gamma(shape=2.0, scale=3.0, size=31).round(1)
readings[:7]
# Out:
# array([3.4, 3.5, 3.4, 4.5, 4.4, 7.1, 5.8])

# %%
total = readings.sum()
wettest = readings.max()
print(f'total {total:.1f} mm')
print(f'wettest day {wettest:.1f} mm')
# Out:
# total 150.6 mm
# wettest day 11.7 mm

# %%
fig, ax = plt.subplots()
ax.bar(range(1, len(readings) + 1), readings)
ax.set_xlabel('day')
ax.set_ylabel('rainfall (mm)')
fig

# %% [markdown]
# ## Notes
#
# Readings are provisional until the station is recalibrated.
