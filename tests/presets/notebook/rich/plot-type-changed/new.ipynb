# %% [markdown]
# # Rainfall summary
#
# A short look at a month of rainfall readings.

# %% [raw]
# dataset: rainfall-2026-07
# source: station 14

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(20260819)

# %%
readings = rng.gamma(shape=2.0, scale=3.0, size=31).round(1)
readings[:7]
# Out:
# array([ 7.4, 10.8,  3.6,  1.5,  4.7,  0.6,  0.8])

# %%
total = readings.sum()
wettest = readings.max()
print(f'total {total:.1f} mm')
print(f'wettest day {wettest:.1f} mm')
# Out:
# total 177.2 mm
# wettest day 26.6 mm

# %%
fig, ax = plt.subplots()
ax.plot(range(1, len(readings) + 1), readings, marker='o')
ax.set_xlabel('day')
ax.set_ylabel('rainfall (mm)')
# dont just leave `fig` at the end here, it duplicates plot for some cryptic reason
plt.show()

# %% [markdown]
# ## Notes
#
# Readings are provisional until the station is recalibrated.
